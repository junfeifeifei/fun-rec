# %% [markdown]
# # 新闻推荐系统：数据理解
#
# 本项目使用 `data/dataset/news_recommendation` 下的新闻数据集，目标是用离线评估的方式搭建完整的召回与排序流程。

# %%
import os
from pathlib import Path

import numpy as np
import pandas as pd

from funrec.utils import load_env_with_fallback

load_env_with_fallback()
RAW_DATA_PATH = Path(os.getenv('FUNREC_RAW_DATA_PATH'))
DATA_PATH = RAW_DATA_PATH / 'dataset' / 'news_recommendation'
if not DATA_PATH.exists():
    DATA_PATH = RAW_DATA_PATH / 'news_recommendation'

DATA_PATH
# Out:
# PosixPath('/Users/wangjunfei/Desktop/fun-rec/data/dataset/news_recommendation')

# %%
train_click = pd.read_csv(DATA_PATH / 'train_click_log.csv')
test_click = pd.read_csv(DATA_PATH / 'testA_click_log.csv')
articles = pd.read_csv(DATA_PATH / 'articles.csv')
article_emb = pd.read_csv(DATA_PATH / 'articles_emb.csv')

pd.DataFrame(
    {
        'name': ['train_click', 'test_click', 'articles', 'article_emb'],
        'rows': [
            len(train_click),
            len(test_click),
            len(articles),
            len(article_emb),
        ],
        'cols': [
            train_click.shape[1],
            test_click.shape[1],
            articles.shape[1],
            article_emb.shape[1],
        ],
    }
)
# Out:
#           name     rows  cols
# 0  train_click  1112623     9
# 1   test_click   518010     9
# 2     articles   364047     4
# 3  article_emb   364047   251

# %% [markdown]
# ## 核心字段

# %%
train_click.head()
# Out:
#    user_id  click_article_id  click_timestamp  click_environment  \
# 0   199999            160417    1507029570190                  4
# 1   199999              5408    1507029571478                  4
# 2   199999             50823    1507029601478                  4
# 3   199998            157770    1507029532200                  4
# 4   199998             96613    1507029671831                  4
#
#    click_deviceGroup  click_os  click_country  click_region  \
# 0                  1        17              1            13
# 1                  1        17              1            13
# 2                  1        17              1            13
# 3                  1        17              1            25
# 4                  1        17              1            25
#
#    click_referrer_type
# 0                    1
# 1                    1
# 2                    1
# 3                    5
# 4                    5

# %% [markdown]
# ## 用户与物品规模

# %%
train_click['user_id'].nunique(), train_click['click_article_id'].nunique()
# Out:
# (200000, 31116)

# %%
train_click['click_dt'] = pd.to_datetime(train_click['click_timestamp'], unit='ms')
articles['created_dt'] = pd.to_datetime(articles['created_at_ts'], unit='ms')

train_click[['click_dt']].describe()
# Out:
#                             click_dt
# count                        1112623
# mean   2017-10-09 22:20:43.096037888
# min       2017-10-03 11:18:52.200000
# 25%    2017-10-06 13:33:20.235999744
# 50%    2017-10-10 00:44:23.470000128
# 75%    2017-10-12 20:36:07.384499968
# max       2017-11-13 20:04:14.886000

# %% [markdown]
# ## 用户点击分布

# %%
import matplotlib.pyplot as plt
import seaborn as sns

user_clicks = train_click.groupby('user_id').size()
user_clicks.describe()
# Out:
# count    200000.000000
# mean          5.563115
# std           6.533846
# min           2.000000
# 25%           2.000000
# 50%           3.000000
# 75%           6.000000
# max         241.000000
# dtype: float64

# %%
plt.figure(figsize=(6, 3))
sns.histplot(user_clicks, bins=50)
plt.yscale('log')
plt.title('User click count distribution (log y)')
# Out:
# Text(0.5, 1.0, 'User click count distribution (log y)')

# %% [markdown]
# ## 热门类别

# %%
top_categories = articles['category_id'].value_counts().head(20).rename('count')
top_categories
# Out:
# category_id
# 281    12817
# 375    10005
# 399     9049
# 412     8648
# 431     7759
# 428     7731
# 26      7343
# 7       6726
# 299     6634
# 301     6446
# 228     6421
# 442     6112
# 437     6017
# 118     5652
# 209     5615
# 354     5496
# 6       5216
# 136     5182
# 455     5138
# 174     5068
# Name: count, dtype: int64

# %%
top_categories.plot(kind='bar', figsize=(6, 3), title='Top categories')
# Out:
# <Axes: title={'center': 'Top categories'}, xlabel='category_id'>
