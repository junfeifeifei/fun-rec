# %% [markdown]
# # 新闻推荐系统增强版（Plus）\n\n本目录用于承载基础版（1-6）之上的增强模块（7-12）。\n\n## 建议运行顺序\n\n1. 先跑基础版：`news_recommendation_system/1-6`（生成 `tmp/projects/news_recommendation_system/` 的中间产物）\n2. 再跑增强版：本目录 `7-12`\n\n## Notebooks\n\n- 7. `7.two_tower_recall.ipynb`：双塔召回训练 + FAISS\n- 8. `8.deep_ranking.ipynb`：DeepFM / DIN 排序\n- 9. `9.sequence_modeling.ipynb`：SASRec / DIEN 序列推荐\n- 10. `10.multi_task.ipynb`：MMoE / ESMM / PLE 多任务\n- 11. `11.evaluation.ipynb`：统一评估与报告\n- 12. `12.model_serving.ipynb`：导出与部署\n
