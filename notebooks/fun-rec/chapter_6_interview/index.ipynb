# %% [markdown]
# ﻿# 面试经验
# :label:`chap_interview`
#
# :begin_tab:toc
#  - [1.machine_learning.md](1.machine_learning.md.ipynb)
#  - [2.recommender.md](2.recommender.md.ipynb)
#  - [3.trends.md](3.trends.md.ipynb)
#  - [4.product.md](4.product.md.ipynb)
#  - [5.hr_other.md](5.hr_other.md.ipynb)
# :end_tab:
